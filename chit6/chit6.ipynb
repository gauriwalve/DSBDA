# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('forestfires.csv')

# %%
df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
sns.scatterplot(x='month', y='temp', data=df,hue='day')
plt.title('Scatter Chart')
plt.show()

# %%
# Box Plot
df.boxplot(by ='day', column =['temp'], grid = False)
# Out:
# <Axes: title={'center': 'temp'}, xlabel='day'>

# %%
# in seaborn the histplot attribute is use for ploting histogram
sns.histplot(df['DMC'])
plt.title("Histogram")
# Adding the legends
plt.show()

# %%
# Pie Chart
keys='FFMC','DMC','DC'
sizes=[df['FFMC'].sum(),df['DMC'].sum(),df['DC'].sum()]
# Plotting data on chart
plt.pie(sizes, labels=keys, autopct='%.0f%%')
# Add title to the chart
plt.title('Values of fire weather indices')
# Displaying chart
plt.show()

# %%
# draw lineplot
sns.lineplot(x="month", y="temp", data=df)
# setting the title
plt.title('Line Chart')
plt.show()
